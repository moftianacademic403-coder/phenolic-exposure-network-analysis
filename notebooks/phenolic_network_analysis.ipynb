# %%
from pathlib import Path
import runpy

PROJECT_ROOT = Path.cwd().resolve()
if PROJECT_ROOT.name == "notebooks":
    PROJECT_ROOT = PROJECT_ROOT.parent

runpy.run_path(
    str(PROJECT_ROOT / "src" / "phenolic_network_analysis.py"),
    run_name="__main__",
)
